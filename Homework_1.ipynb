# %% [markdown]
# # PART A:
# ### 1. Find the url for the mtcars dataset from the following website: https://vincentarelbundock.github.io/Rdatasets/datasets.html. Read through the "DOC" file to understand the variables in the dataset, then use the following url to import the data using pandas read_csv() function. https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv.

# %%
# Import Python Libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load mtcars (Motor Trend Car Road Tests) dataset
mtcars = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv")

# Description: The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption
# and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).

# %% [markdown]
# ### 2. Display the first five rows of the data.

# %%
# List first 5 records
mtcars.head()
# Out:
#             rownames   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# ### 3. For each category in the cyl column, calculate the average mpg for all cars with that cyl value.

# %%
# Calculate mean mpg for each cyl category
mtcars.groupby('cyl')[['mpg']].mean()
# Out:
#            mpg
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000

# %% [markdown]
# ### 4. Create a histogram using the mpg column. Remember to label your axes.

# %%
# Histogram
mtcars['mpg'].hist()

plt.title("Histogram of MPG")
plt.xlabel('MPG')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### 5. Choose two variables in the data and create a scatterplot. Remember to label your axes.

# %%
# Scatterplot
plt.scatter(mtcars['wt'], mtcars['mpg'])

plt.title("Miles per Gallon by Car Weight")
plt.xlabel("Weight (1000 lbs)")
plt.ylabel("Miles per Gallon (mpg)")
# Out:
# Text(0, 0.5, 'Miles per Gallon (mpg)')

# %% [markdown]
# # Part B:
# ### 1. Find a tabular dataset that interests you that has "tidy" data. Tidy data has data that is ready for your data analysis. For our tasks we want something where columns represent variables and rows represent unique observations. Provide the url for the dataset and a one sentence description of what it is.

# %%
# Load affairs (Fair's Extramarital Affairs Data) dataset
affairs = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv")

# URL for the affairs dataset: https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv

# Description: Infidelity data, known as Fair's Affairs.
# Cross-section data from a survey conducted by Psychology Today in 1969.

# %% [markdown]
# ### 2. Display the first five rows of the data.

# %%
# List first 5 records
affairs.head()
# Out:
#    rownames  affairs  gender   age  yearsmarried children  religiousness  \
# 0         4        0    male  37.0         10.00       no              3
# 1         5        0  female  27.0          4.00       no              4
# 2        11        0  female  32.0         15.00      yes              1
# 3        16        0    male  57.0         15.00      yes              5
# 4        23        0    male  22.0          0.75       no              2
#
#    education  occupation  rating
# 0         18           7       4
# 1         14           6       4
# 2         12           1       4
# 3         18           6       5
# 4         17           6       3

# %% [markdown]
# ### 3. Create a visualization using two variables from this data.

# %%
# Scatterplot

plt.scatter(affairs["age"], affairs["affairs"])

plt.title("Number of Affairs by Age")
plt.xlabel("Age (coded categories)")
plt.ylabel("Number of Affairs (coded)")

# Note: age is coded into age-group categories (e.g., 17.5 = under 20, 22 = 20–24, 57 = 55 or over, etc.),
# so it should be interpreted as an ordered age group measure rather than exact age in years.


# Note: affairs is an ordinal-coded frequency variable (e.g., 0 = none, 1 = once, 2 = twice, 7 = 4–10 times, etc.),
# so the values should be interpreted as frequency categories rather than exact counts.
# Out:
# Text(0, 0.5, 'Number of Affairs (coded)')
